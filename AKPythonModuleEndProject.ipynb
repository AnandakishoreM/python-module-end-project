# %% [raw]
# #Python Module End Project

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("myexcel - myexcel.csv.csv")
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# ##1.How many are there in each Team and the percentage splitting with respect to the total employees.

# %%
df1=df
r=np.random.randint(150,180,458)
df1["Height"]=r
df1["Height"]=df1["Height"].astype("int64")
df1
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     166     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     162     235
# 2     John Holland  Boston Celtics      30       SG   27     151     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     165     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     164     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     167     203
# 454      Raul Neto       Utah Jazz      25       PG   24     155     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     173     256
# 456    Jeff Withey       Utah Jazz      24        C   26     157     231
# 457       Priyanka       Utah Jazz      34        C   25     177     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df1[pd.isnull(df1["Salary"])]
# Out:
#                Name                    Team  Number Position  Age  Height  \
# 2      John Holland          Boston Celtics      30       SG   27     151
# 46      Elton Brand      Philadelphia 76ers      42       PF   37     165
# 171   Dahntay Jones     Cleveland Cavaliers      30       SG   35     163
# 264   Jordan Farmar       Memphis Grizzlies       4       PG   29     159
# 269    Ray McCallum       Memphis Grizzlies       5       PG   24     154
# 270  Xavier Munford       Memphis Grizzlies      14       PG   24     177
# 273  Alex Stepheson       Memphis Grizzlies      35       PF   28     171
# 350   Briante Weber              Miami Heat      12       PG   23     166
# 353   Dorell Wright              Miami Heat      11       SF   30     170
# 397    Axel Toupane          Denver Nuggets       6       SG   23     172
# 409      Greg Smith  Minnesota Timberwolves       4       PF   25     157
#
#      Weight                College  Salary
# ...

# %%
df1a=df1
avg=df1a["Salary"].mean()
print(avg)
# Out:
# 4833969.545861297

# %%
a1=df1a.loc[df1a["Team"]=="Boston Celtics","Salary"].mean()
round(a1,1)
# Out:
# 4181504.9

# %%
a2=df1a.loc[df1a["Team"]=="Philadelphia 76ers","Salary"].mean()
round(a2,1)
# Out:
# 2213778.1

# %%
a3=df1a.loc[df1a["Team"]=="Cleveland Cavaliers","Salary"].mean()
round(a3,1)
# Out:
# 7642049.2

# %%
a4=df1a.loc[df1a["Team"]=="Memphis Grizzlies","Salary"].mean()
round(a4,1)
# Out:
# 5467920.0

# %%
a5=df1a.loc[df1a["Team"]=="Miami Heat","Salary"].mean()
round(a5,1)
# Out:
# 6347359.5

# %%
a6=df1a.loc[df1a["Team"]=="Denver Nuggets","Salary"].mean()
round(a6,1)
# Out:
# 4294423.6

# %%
a7=df1a.loc[df1a["Team"]=="Minnesota Timberwolves","Salary"].mean()
round(a7,1)
# Out:
# 4593053.6

# %%
df1a.Team.unique()
# Out:
# array(['Boston Celtics', 'Brooklyn Nets', 'New York Knicks',
#        'Philadelphia 76ers', 'Toronto Raptors', 'Golden State Warriors',
#        'Los Angeles Clippers', 'Los Angeles Lakers', 'Phoenix Suns',
#        'Sacramento Kings', 'Chicago Bulls', 'Cleveland Cavaliers',
#        'Detroit Pistons', 'Indiana Pacers', 'Milwaukee Bucks',
#        'Dallas Mavericks', 'Houston Rockets', 'Memphis Grizzlies',
#        'New Orleans Pelicans', 'San Antonio Spurs', 'Atlanta Hawks',
#        'Charlotte Hornets', 'Miami Heat', 'Orlando Magic',
#        'Washington Wizards', 'Denver Nuggets', 'Minnesota Timberwolves',
#        'Oklahoma City Thunder', 'Portland Trail Blazers', 'Utah Jazz'],
#       dtype=object)

# %%
swaps = {
    "Boston Celtics":4181504.9,
    "Philadelphia 76ers": 2213778.1,
    "Cleveland Cavaliers":7642049.2,
    "Memphis Grizzlies": 5467920.0,
    "Miami Heat": 6347359.5,
    "Denver Nuggets":4294423.6,
    "Minnesota Timberwolves":4593053.6,
    'Brooklyn Nets':0,
    'New York Knicks':0,
    'Toronto Raptors':0,
    'Golden State Warriors':0,
    'Los Angeles Clippers':0, 
    'Los Angeles Lakers':0,
    'Phoenix Suns':0,
    'Sacramento Kings':0, 
    'Chicago Bulls':0,
    'Detroit Pistons':0, 
    'Indiana Pacers':0, 
    'Milwaukee Bucks':0,
    'Dallas Mavericks':0, 
    'Houston Rockets':0,
    'New Orleans Pelicans':0, 
    'San Antonio Spurs':0, 
    'Atlanta Hawks':0,
    'Charlotte Hornets':0, 
    'Orlando Magic':0,
    'Washington Wizards':0,
    'Oklahoma City Thunder':0, 
    'Portland Trail Blazers':0, 
    'Utah Jazz':0}
sal1 = df1a.apply(lambda row: swaps[row["Team"]],axis=1,)
df1a["Salary"] = df1a["Salary"].fillna(sal1)

# %%
df1a
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     166     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     162     235
# 2     John Holland  Boston Celtics      30       SG   27     151     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     165     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     164     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     167     203
# 454      Raul Neto       Utah Jazz      25       PG   24     155     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     173     256
# 456    Jeff Withey       Utah Jazz      24        C   26     157     231
# 457       Priyanka       Utah Jazz      34        C   25     177     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df1a.College.value_counts()
# Out:
# College
# Kentucky               22
# Duke                   20
# Kansas                 19
# North Carolina         16
# UCLA                   15
#                        ..
# Iowa                    1
# St. Bonaventure         1
# Louisiana-Lafayette     1
# Georgia State           1
# Boston University       1
# Name: count, Length: 118, dtype: int64

# %%
df1a["College"].fillna(df1a["College"].mode(),inplace=True)
df1a
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     166     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     162     235
# 2     John Holland  Boston Celtics      30       SG   27     151     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     165     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     164     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     167     203
# 454      Raul Neto       Utah Jazz      25       PG   24     155     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     173     256
# 456    Jeff Withey       Utah Jazz      24        C   26     157     231
# 457       Priyanka       Utah Jazz      34        C   25     177     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df1a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    int64
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    458 non-null    float64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 32.3+ KB

# %%
df1p=pd.DataFrame(df1a.Team.value_counts())
df1p
# Out:
#                         count
# Team
# New Orleans Pelicans       19
# Memphis Grizzlies          18
# Utah Jazz                  16
# Milwaukee Bucks            16
# New York Knicks            16
# Boston Celtics             15
# Los Angeles Clippers       15
# Los Angeles Lakers         15
# Phoenix Suns               15
# Sacramento Kings           15
# Brooklyn Nets              15
# Philadelphia 76ers         15
# Toronto Raptors            15
# Golden State Warriors      15
# Indiana Pacers             15
# Detroit Pistons            15
# Cleveland Cavaliers        15
# Chicago Bulls              15
# Houston Rockets            15
# San Antonio Spurs          15
# Atlanta Hawks              15
# Dallas Mavericks           15
# Charlotte Hornets          15
# Miami Heat                 15
# Denver Nuggets             15
# Washington Wizards         15
# Portland Trail Blazers     15
# Oklahoma City Thunder      15
# Orlando Magic              14
# Minnesota Timberwolves     14

# %%
df1p.plot.pie(y="count",figsize=(8,8),autopct='%1.1f%%', startangle=90, radius=1.2)
plt.legend(bbox_to_anchor=(1.5, 1), loc='upper left')
plt.show()

# %% [markdown]
# ##2.Segregate the employees w.r.t different positions.

# %%
df2=df1a
df2.Position.unique()
# Out:
# array(['PG', 'SF', 'SG', 'PF', 'C'], dtype=object)

# %%
df2.Position.nunique()
# Out:
# 5

# %%
df2.groupby("Position")["Name"].nunique()
# Out:
# Position
# C      79
# PF    100
# PG     92
# SF     85
# SG    102
# Name: Name, dtype: int64

# %%
df2a=pd.DataFrame(df2.groupby("Position")["Name"].nunique())
df2a
# Out:
#           Name
# Position
# C           79
# PF         100
# PG          92
# SF          85
# SG         102

# %%
df2a.plot.pie(y="Name",autopct='%1.1f%%')
plt.legend(bbox_to_anchor=(1.5, 1), loc='upper left')
plt.show()

# %%
df2b=df2.groupby("Position")
df2b.describe()
# Out:
#          Number                                                       Age  \
#           count       mean        std  min   25%   50%   75%   max  count
# Position
# C          79.0  21.962025  16.612046  0.0  11.5  17.0  29.5  92.0   79.0
# PF        100.0  23.570000  20.107918  0.0   6.0  21.5  35.0  90.0  100.0
# PG         92.0  10.967391  11.982085  0.0   2.0   8.0  14.0  55.0   92.0
# SF         85.0  17.611765  14.904533  0.0   7.0  15.0  24.0  99.0   85.0
# SG        102.0  14.852941  11.497221  0.0   5.0  11.0  23.0  55.0  102.0
#
#                      ... Weight        Salary                              \
#                mean  ...    75%    max  count          mean           std
# Position             ...
# C         27.341772  ...  265.0  307.0   79.0  5.903511e+06  5.778432e+06
# PF        27.160000  ...  250.0  275.0  100.0  4.548356e+06  4.733511e+06
# PG        26.847826  ...  200.0  220.0   92.0  5.104349e+06  4.941761e+06
# ...

# %%
p=df2.groupby("Position")
pC=p.get_group("C")
pPF=p.get_group("PF")
pPG=p.get_group("PG")
pSF=p.get_group("SF")
pSG=p.get_group("SG")
pC
# Out:
#                 Name                    Team  Number Position  Age  Height  \
# 7       Kelly Olynyk          Boston Celtics      41        C   25     154
# 10   Jared Sullinger          Boston Celtics       7        C   24     154
# 14      Tyler Zeller          Boston Celtics      44        C   26     173
# 23       Brook Lopez           Brooklyn Nets      11        C   28     163
# 27        Henry Sims           Brooklyn Nets      14        C   26     173
# ..               ...                     ...     ...      ...  ...     ...
# 439    Mason Plumlee  Portland Trail Blazers      24        C   26     174
# 447      Rudy Gobert               Utah Jazz      27        C   23     170
# 455     Tibor Pleiss               Utah Jazz      21        C   26     173
# 456      Jeff Withey               Utah Jazz      24        C   26     157
# 457         Priyanka               Utah Jazz      34        C   25     177
#
#      Weight         College      Salary
# ...

# %%
pPF
# Out:
#                  Name                    Team  Number Position  Age  Height  \
# 4       Jonas Jerebko          Boston Celtics       8       PF   29     164
# 5        Amir Johnson          Boston Celtics      90       PF   29     157
# 6       Jordan Mickey          Boston Celtics      55       PF   21     150
# 24   Chris McCullough           Brooklyn Nets       1       PF   21     154
# 25        Willie Reed           Brooklyn Nets      33       PF   26     157
# ..                ...                     ...     ...      ...  ...     ...
# 435    Meyers Leonard  Portland Trail Blazers      11       PF   24     157
# 441       Noah Vonleh  Portland Trail Blazers      21       PF   20     165
# 442     Trevor Booker               Utah Jazz      33       PF   28     172
# 446    Derrick Favors               Utah Jazz      15       PF   24     158
# 452        Trey Lyles               Utah Jazz      41       PF   20     164
#
#      Weight       College      Salary
# ...

# %%
pPG
# Out:
#               Name                    Team  Number Position  Age  Height  \
# 0    Avery Bradley          Boston Celtics       0       PG   25     166
# 8     Terry Rozier          Boston Celtics      12       PG   22     175
# 9     Marcus Smart          Boston Celtics      36       PG   22     178
# 11   Isaiah Thomas          Boston Celtics       4       PG   27     150
# 19    Jarrett Jack           Brooklyn Nets       2       PG   32     163
# ..             ...                     ...     ...      ...  ...     ...
# 440  Brian Roberts  Portland Trail Blazers       2       PG   30     154
# 443     Trey Burke               Utah Jazz       3       PG   23     164
# 445     Dante Exum               Utah Jazz      11       PG   20     174
# 453   Shelvin Mack               Utah Jazz       8       PG   26     167
# 454      Raul Neto               Utah Jazz      25       PG   24     155
#
#      Weight         College     Salary
# 0       180           Texas  7730337.0
# ...

# %%
pSF
# Out:
#                        Name                    Team  Number Position  Age  \
# 1               Jae Crowder          Boston Celtics      99       SF   25
# 32   Thanasis Antetokounmpo         New York Knicks      43       SF   23
# 33          Carmelo Anthony         New York Knicks       7       SF   32
# 35         Cleanthony Early         New York Knicks      11       SF   25
# 42             Lance Thomas         New York Knicks      42       SF   28
# ..                      ...                     ...     ...      ...  ...
# 428         Al-Farouq Aminu  Portland Trail Blazers       8       SF   25
# 432        Maurice Harkless  Portland Trail Blazers       4       SF   23
# 448          Gordon Hayward               Utah Jazz      20       SF   26
# 450              Joe Ingles               Utah Jazz       2       SF   28
# 451           Chris Johnson               Utah Jazz      23       SF   26
#
#      Height  Weight        College      Salary
# ...

# %%
pSG
# Out:
#                  Name                    Team  Number Position  Age  Height  \
# 2        John Holland          Boston Celtics      30       SG   27     151
# 3         R.J. Hunter          Boston Celtics      28       SG   22     165
# 12        Evan Turner          Boston Celtics      11       SG   27     167
# 13        James Young          Boston Celtics      13       SG   20     174
# 15   Bojan Bogdanovic           Brooklyn Nets      44       SG   27     177
# ..                ...                     ...     ...      ...  ...     ...
# 433  Gerald Henderson  Portland Trail Blazers       9       SG   28     153
# 437     C.J. McCollum  Portland Trail Blazers       3       SG   24     166
# 438      Luis Montero  Portland Trail Blazers      44       SG   23     169
# 444        Alec Burks               Utah Jazz      10       SG   24     161
# 449       Rodney Hood               Utah Jazz       5       SG   23     169
#
#      Weight            College     Salary
# ...

# %% [markdown]
# ##3.Find from which age group most of the employees belong to.

# %%
df3=df2["Age"]
df3
# Out:
# 0      25
# 1      25
# 2      27
# 3      22
# 4      29
#        ..
# 453    26
# 454    24
# 455    26
# 456    26
# 457    25
# Name: Age, Length: 458, dtype: int64

# %%
df3a=df1a.groupby("Age")["Name"].nunique()
df3a
# Out:
# Age
# 19     2
# 20    19
# 21    19
# 22    26
# 23    41
# 24    47
# 25    46
# 26    36
# 27    41
# 28    31
# 29    28
# 30    31
# 31    22
# 32    13
# 33    14
# 34    10
# 35     9
# 36    10
# 37     4
# 38     4
# 39     2
# 40     3
# Name: Name, dtype: int64

# %%
df3a.max()
# Out:
# 47

# %% [markdown]
# ##4.Find out under which team and position, spending in terms of salary is high.

# %%
df4a=df1a.sort_values(by="Salary",ascending=False).head(1)
df4a
# Out:
#             Name                Team  Number Position  Age  Height  Weight  \
# 109  Kobe Bryant  Los Angeles Lakers      24       SF   37     154     212
#
#     College      Salary
# 109     NaN  25000000.0

# %%
df4a["Team"]
# Out:
# 109    Los Angeles Lakers
# Name: Team, dtype: object

# %%
df4a["Position"]
# Out:
# 109    SF
# Name: Position, dtype: object

# %% [markdown]
# ##5.Find if there is any correlation between age and salary , represent it visually.

# %%
df5=df1a[["Age","Salary"]]
df5
# Out:
#      Age     Salary
# 0     25  7730337.0
# 1     25  6796117.0
# 2     27  4181504.9
# 3     22  1148640.0
# 4     29  5000000.0
# ..   ...        ...
# 453   26  2433333.0
# 454   24   900000.0
# 455   26  2900000.0
# 456   26   947276.0
# 457   25   947276.0
#
# [458 rows x 2 columns]

# %%
df5.plot.scatter(x="Age",y="Salary")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Salary'>

# %%
df1a.to_csv("MEproject.csv")
